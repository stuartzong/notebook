# %%
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib import style, colors
from matplotlib import gridspec

matplotlib.style.use('ggplot')
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (8, 6)

# %% [markdown]
# # make oncoprint for 124 patients

# %%
f1 ='/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients/HIGH_MODERATE_INDEL_summary_with_normal_strelka_only.tsv'
indf = pd.read_csv(f1, sep='\t')
indf.head(2)
# Out:
#     gene  num_patients_gene_level  num_INDELs_gene_level chromosome  position  \
# 0  ABCA9                        2                      3         17  66992092
# 1  ABCB5                        1                      1          7  20767995
#
#   ref_base alt_base  num_patients_INDEL_level         patient_ID     snp_ID  \
# 0        C       CA                         1  HTMCP-03-06-02007  novel_snp
# 1     TATA        T                         1  HTMCP-03-06-02202  novel_snp
#
#       ...      pileup_AltC pileup_AF strelka_n_Cov strelka_n_RefC  \
# 0     ...               na        na            54             51
# 1     ...               na        na            44             45
#
#   strelka_n_AltC strelka_n_AF strelka_t_Cov strelka_t_RefC strelka_t_AltC  \
# 0              0          0.0            78             41             29
# 1              0          0.0            66             42             18
#
#   strelka_t_AF
# 0         0.41
# 1         0.30
#
# [2 rows x 29 columns]

# %%
indf['impact_tmp'] = indf['snpeff_details'].apply(lambda x: x.split('(')[0])
indf = indf[['gene', 'patient_ID','impact_tmp']]
indf.head()
# Out:
#            gene         patient_ID        impact_tmp
# 0         ABCA9  HTMCP-03-06-02007       FRAME_SHIFT
# 1         ABCB5  HTMCP-03-06-02202  inframe_deletion
# 2  ABHD14A-ACY1  HTMCP-03-06-02441       FRAME_SHIFT
# 3       ABHD16A  HTMCP-03-06-02435       FRAME_SHIFT
# 4    AC006035.2  HTMCP-03-06-02007       FRAME_SHIFT

# %%
# get gene list
f2 = '/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients/genes.txt'
cdf = pd.read_csv(f2)
genes = cdf.genes.tolist()
print(genes)
# Out:
# ['YAP1', 'AJUBA', 'ARID1A', 'ATR', 'ATRX', 'B2M', 'CASP8', 'CBFB', 'ELF3', 'EP300', 'ERBB2', 'ERBB3', 'FAT1', 'FAT2', 'FBXW7', 'HLA-A', 'HLA-B', 'HLA-C', 'KRAS', 'LRP1B', 'MAGEC1', 'MAPK1', 'MLL', 'MLL2', 'MLL3', 'NFE2L2', 'PIK3CA', 'PTEN', 'RB1', 'SF3B1', 'SHKBP1', 'STK11', 'TGFBR2', 'TP53', 'TPR', 'U2AF1', 'ZRSR2']

# %%
# get meta track for example histology
f3 ='/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients/mutation_load_clinic.txt'
ddf = pd.read_csv(f3, sep='\t')
ddf = ddf[['patient', 'reanne_HIV_status', 'reanne_Putative_histology']]
edf = ddf.set_index('patient').T
edf.head(2)
# Out:
# patient                   HTMCP-03-06-02001 HTMCP-03-06-02002  \
# reanne_HIV_status                  Positive          Negative
# reanne_Putative_histology          Squamous          Squamous
#
# patient                   HTMCP-03-06-02003 HTMCP-03-06-02006  \
# reanne_HIV_status                  Positive          Negative
# reanne_Putative_histology          Squamous          Squamous
#
# patient                   HTMCP-03-06-02007 HTMCP-03-06-02008  \
# reanne_HIV_status                  Negative          Negative
# reanne_Putative_histology             Adeno          Squamous
#
# patient                   HTMCP-03-06-02012 HTMCP-03-06-02013  \
# reanne_HIV_status                  Negative          Negative
# reanne_Putative_histology          Squamous          Squamous
#
# patient                   HTMCP-03-06-02020 HTMCP-03-06-02026  \
# reanne_HIV_status                  Positive          Negative
# reanne_Putative_histology          Squamous             Adeno
#
# patient                          ...        HTMCP-03-06-02424  \
# reanne_HIV_status                ...                 Positive
# reanne_Putative_histology        ...                 Squamous
#
# patient                   HTMCP-03-06-02427 HTMCP-03-06-02428  \
# reanne_HIV_status                  Positive          Positive
# reanne_Putative_histology          Squamous          Squamous
#
# patient                   HTMCP-03-06-02434 HTMCP-03-06-02435  \
# reanne_HIV_status                  Positive          Positive
# reanne_Putative_histology          Squamous          Squamous
#
# patient                   HTMCP-03-06-02437 HTMCP-03-06-02441  \
# reanne_HIV_status                  Positive          Positive
# reanne_Putative_histology          Squamous             Adeno
#
# patient                   HTMCP-03-06-02442 HTMCP-03-06-02447  \
# reanne_HIV_status                  Positive          Positive
# reanne_Putative_histology          Squamous          Squamous
#
# patient                   HTMCP-03-06-02448
# reanne_HIV_status                  Positive
# reanne_Putative_histology             Adeno
#
# [2 rows x 123 columns]

# %%
# get snvs
f4 = '/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients/124_patients_selected_columns_new_filtered.txt'
pdf = pd.read_csv(f4, sep='\t')
pdf.head(2)
pdf['impact_tmp'] = pdf['snpeff_details'].apply(lambda x: x.split('(')[0])
mdf = pdf[['gene', 'patient_ID','impact_tmp']]
# Out:
# /home/szong/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# concat indel and snvs
rdf = pd.concat([mdf,indf])
rdf.head(2)
# Out:
#      gene         patient_ID             impact_tmp
# 0  SAMD11  HTMCP-03-06-02007  NON_SYNONYMOUS_CODING
# 1  SAMD11  HTMCP-03-06-02214  NON_SYNONYMOUS_CODING

# %%
rdf = rdf.drop_duplicates().groupby(['gene', 'patient_ID']).agg({'impact_tmp': ','.join}).reset_index()
rdf.head(2)
# Out:
#    gene         patient_ID             impact_tmp
# 0  A1BG  HTMCP-03-06-02179  NON_SYNONYMOUS_CODING
# 1  A1CF  HTMCP-03-06-02020  NON_SYNONYMOUS_CODING

# %%
def impact_type(x):
#     print(x)
    xsplit = list(set(x.split(',')))
    type = xsplit[0].upper()
    if len(xsplit) > 1:
        impact = 'Multiple'
    elif len(xsplit) == 1:
         if '+' in xsplit[0]:
             impact = 'Multiple'
         elif type == 'MISSENSE_VARIANT' or type == 'NON_SYNONYMOUS_CODING':
             impact = 'NON_SYNONYMOUS_CODING'
         elif  type == 'SPLICE_SITE_ACCEPTOR' or  type == 'SPLICE_SITE_DONOR':
             impact = 'SPLICE_ACCEPTOR_DONOR'
         elif type == 'STOP_LOST':
             impact = 'STOP_LOST'
         elif type == 'STOP_GAINED':
             impact = 'STOP_GAINED'
         elif  type == 'START_LOST':
             impact = 'START_LOST'
         elif type == 'START_GAINED':
             impact = 'START_GAINED'
         elif type == 'FRAME_SHIFT' or type == 'FRAMESHIFT_VARIANT':
             impact = 'FRAME_SHIFT'
         elif type == 'INFRAME_DELETION' or type == 'CODON_INSERTION' or type == 'CODON_DELETION' or type == 'CODON_CHANGE_PLUS_CODON_INSERTION' or type == 'CODON_CHANGE_PLUS_CODON_DELETION' or type.lower() == 'disruptive_inframe_deletion':
             impact = 'CODON_INSERTION_DELETION'                
         else: exit(1);print('ERROR')
    return impact

# %%
rdf['impact'] = rdf['impact_tmp'].apply(lambda x: impact_type(x))
rdf = rdf[['gene', 'patient_ID', 'impact']].drop_duplicates()
rdf = rdf.set_index(['gene', 'patient_ID'])['impact'].unstack()
rdf.head(2)
# Out:
# patient_ID HTMCP-03-06-02001 HTMCP-03-06-02002 HTMCP-03-06-02003  \
# gene
# A1BG                    None              None              None
# A1CF                    None              None              None
#
# patient_ID HTMCP-03-06-02006 HTMCP-03-06-02007 HTMCP-03-06-02008  \
# gene
# A1BG                    None              None              None
# A1CF                    None              None              None
#
# patient_ID HTMCP-03-06-02012 HTMCP-03-06-02013      HTMCP-03-06-02020  \
# gene
# A1BG                    None              None                   None
# A1CF                    None              None  NON_SYNONYMOUS_CODING
#
# patient_ID HTMCP-03-06-02026        ...        HTMCP-03-06-02424  \
# gene                                ...
# A1BG                    None        ...                     None
# A1CF                    None        ...                     None
#
# patient_ID HTMCP-03-06-02427 HTMCP-03-06-02428 HTMCP-03-06-02434  \
# gene
# A1BG                    None              None              None
# A1CF                    None              None              None
#
# patient_ID HTMCP-03-06-02435 HTMCP-03-06-02437 HTMCP-03-06-02441  \
# gene
# A1BG                    None              None              None
# A1CF                    None              None              None
#
# patient_ID HTMCP-03-06-02442 HTMCP-03-06-02447 HTMCP-03-06-02448
# gene
# A1BG                    None              None              None
# A1CF                    None              None              None
#
# [2 rows x 124 columns]

# %%
# of3 = '/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/107_patients/mutations_in_oncoprint.txt'
# rdf.fillna('NA').to_csv(of3, sep='\t')

# %%
rdf = pd.concat([rdf, edf])

# %%
rdf.index
# Out:
# Index(['A1BG', 'A1CF', 'A2LD1', 'A2M', 'A2ML1', 'A4GALT', 'A4GNT', 'AAAS',
#        'AACS', 'AADAC',
#        ...
#        'ZXDC', 'ZYG11A', 'ZYG11B', 'ZZEF1', 'ZZZ3', 'hsa-mir-3187',
#        'hsa-mir-4763', 'yR211F11.2', 'reanne_HIV_status',
#        'reanne_Putative_histology'],
#       dtype='object', length=14575)

# %%
genes = [ 'reanne_HIV_status', 'reanne_Putative_histology'] + genes

# %%
rdf = rdf.reindex(genes)#.loc['PIK3CA'].value_counts()
rdf.head(3)
pd.Series(rdf.values.ravel()).unique()
# Out:
# array(['Positive', 'Negative', nan, 'Squamous', 'Adeno', None,
#        'NON_SYNONYMOUS_CODING', 'FRAME_SHIFT', 'Multiple', 'STOP_GAINED',
#        'SPLICE_ACCEPTOR_DONOR', 'CODON_INSERTION_DELETION'], dtype=object)

# %%
rdf['occurrence'] = (rdf.notnull().sum(axis=1)/(rdf.shape[1] -2))

# %%
genes = rdf['occurrence'].sort_values(ascending=False).index.tolist()
# genes

# %%
rdf = rdf.reindex(genes)
rdf.head(2)
# Out:
#                           HTMCP-03-06-02001 HTMCP-03-06-02002  \
# reanne_HIV_status                  Positive          Negative
# reanne_Putative_histology          Squamous          Squamous
#
#                           HTMCP-03-06-02003 HTMCP-03-06-02006  \
# reanne_HIV_status                  Positive          Negative
# reanne_Putative_histology          Squamous          Squamous
#
#                           HTMCP-03-06-02007 HTMCP-03-06-02008  \
# reanne_HIV_status                  Negative          Negative
# reanne_Putative_histology             Adeno          Squamous
#
#                           HTMCP-03-06-02012 HTMCP-03-06-02013  \
# reanne_HIV_status                  Negative          Negative
# reanne_Putative_histology          Squamous          Squamous
#
#                           HTMCP-03-06-02020 HTMCP-03-06-02026    ...      \
# reanne_HIV_status                  Positive          Negative    ...
# reanne_Putative_histology          Squamous             Adeno    ...
#
#                           HTMCP-03-06-02427 HTMCP-03-06-02428  \
# reanne_HIV_status                  Positive          Positive
# reanne_Putative_histology          Squamous          Squamous
#
#                           HTMCP-03-06-02434 HTMCP-03-06-02435  \
# reanne_HIV_status                  Positive          Positive
# reanne_Putative_histology          Squamous          Squamous
#
#                           HTMCP-03-06-02437 HTMCP-03-06-02441  \
# reanne_HIV_status                  Positive          Positive
# reanne_Putative_histology          Squamous             Adeno
#
#                           HTMCP-03-06-02442 HTMCP-03-06-02447  \
# reanne_HIV_status                  Positive          Positive
# reanne_Putative_histology          Squamous          Squamous
#
#                           HTMCP-03-06-02448 occurrence
# reanne_HIV_status                  Positive   1.008197
# reanne_Putative_histology             Adeno   1.008197
#
# [2 rows x 125 columns]

# %%
rdf['percentage'] = ['{0}({1}%)'.format(i[0], int(round(i[1]*100))) for i in zip(rdf.index.tolist(), rdf.occurrence)]

# %%
rdf.loc['reanne_HIV_status', 'percentage'] = 'HIV_Status'
rdf.loc['reanne_Putative_histology', 'percentage' ] = 'Puatative_Histology'

# %%
rdf.head(3)
# Out:
#                                HTMCP-03-06-02001      HTMCP-03-06-02002  \
# reanne_HIV_status                       Positive               Negative
# reanne_Putative_histology               Squamous               Squamous
# PIK3CA                     NON_SYNONYMOUS_CODING  NON_SYNONYMOUS_CODING
#
#                           HTMCP-03-06-02003 HTMCP-03-06-02006  \
# reanne_HIV_status                  Positive          Negative
# reanne_Putative_histology          Squamous          Squamous
# PIK3CA                                 None              None
#
#                           HTMCP-03-06-02007 HTMCP-03-06-02008  \
# reanne_HIV_status                  Negative          Negative
# reanne_Putative_histology             Adeno          Squamous
# PIK3CA                             Multiple              None
#
#                                HTMCP-03-06-02012      HTMCP-03-06-02013  \
# reanne_HIV_status                       Negative               Negative
# reanne_Putative_histology               Squamous               Squamous
# PIK3CA                     NON_SYNONYMOUS_CODING  NON_SYNONYMOUS_CODING
#
#                           HTMCP-03-06-02020 HTMCP-03-06-02026  \
# reanne_HIV_status                  Positive          Negative
# reanne_Putative_histology          Squamous             Adeno
# PIK3CA                                 None       STOP_GAINED
#
#                                   ...               HTMCP-03-06-02428  \
# reanne_HIV_status                 ...                        Positive
# reanne_Putative_histology         ...                        Squamous
# PIK3CA                            ...           NON_SYNONYMOUS_CODING
#
#                           HTMCP-03-06-02434 HTMCP-03-06-02435  \
# reanne_HIV_status                  Positive          Positive
# reanne_Putative_histology          Squamous          Squamous
# PIK3CA                                 None              None
#
#                           HTMCP-03-06-02437 HTMCP-03-06-02441  \
# reanne_HIV_status                  Positive          Positive
# reanne_Putative_histology          Squamous             Adeno
# PIK3CA                                 None              None
#
#                           HTMCP-03-06-02442      HTMCP-03-06-02447  \
# reanne_HIV_status                  Positive               Positive
# reanne_Putative_histology          Squamous               Squamous
# PIK3CA                                 None  NON_SYNONYMOUS_CODING
#
#                           HTMCP-03-06-02448 occurrence           percentage
# reanne_HIV_status                  Positive   1.008197           HIV_Status
# reanne_Putative_histology             Adeno   1.008197  Puatative_Histology
# PIK3CA                                 None   0.360656          PIK3CA(36%)
#
# [3 rows x 126 columns]

# %%
sdf = rdf.drop('occurrence', axis=1).set_index('percentage', drop=True)

# %%
# sdf = sdf.fillna(0)

# %%
sdf.head(3)
# Out:
#                          HTMCP-03-06-02001      HTMCP-03-06-02002  \
# percentage
# HIV_Status                        Positive               Negative
# Puatative_Histology               Squamous               Squamous
# PIK3CA(36%)          NON_SYNONYMOUS_CODING  NON_SYNONYMOUS_CODING
#
#                     HTMCP-03-06-02003 HTMCP-03-06-02006 HTMCP-03-06-02007  \
# percentage
# HIV_Status                   Positive          Negative          Negative
# Puatative_Histology          Squamous          Squamous             Adeno
# PIK3CA(36%)                      None              None          Multiple
#
#                     HTMCP-03-06-02008      HTMCP-03-06-02012  \
# percentage
# HIV_Status                   Negative               Negative
# Puatative_Histology          Squamous               Squamous
# PIK3CA(36%)                      None  NON_SYNONYMOUS_CODING
#
#                          HTMCP-03-06-02013 HTMCP-03-06-02020  \
# percentage
# HIV_Status                        Negative          Positive
# Puatative_Histology               Squamous          Squamous
# PIK3CA(36%)          NON_SYNONYMOUS_CODING              None
#
#                     HTMCP-03-06-02026        ...        HTMCP-03-06-02424  \
# percentage                                   ...
# HIV_Status                   Negative        ...                 Positive
# Puatative_Histology             Adeno        ...                 Squamous
# PIK3CA(36%)               STOP_GAINED        ...                     None
#
#                     HTMCP-03-06-02427      HTMCP-03-06-02428  \
# percentage
# HIV_Status                   Positive               Positive
# Puatative_Histology          Squamous               Squamous
# PIK3CA(36%)                      None  NON_SYNONYMOUS_CODING
#
#                     HTMCP-03-06-02434 HTMCP-03-06-02435 HTMCP-03-06-02437  \
# percentage
# HIV_Status                   Positive          Positive          Positive
# Puatative_Histology          Squamous          Squamous          Squamous
# PIK3CA(36%)                      None              None              None
#
#                     HTMCP-03-06-02441 HTMCP-03-06-02442  \
# percentage
# HIV_Status                   Positive          Positive
# Puatative_Histology             Adeno          Squamous
# PIK3CA(36%)                      None              None
#
#                          HTMCP-03-06-02447 HTMCP-03-06-02448
# percentage
# HIV_Status                        Positive          Positive
# Puatative_Histology               Squamous             Adeno
# PIK3CA(36%)          NON_SYNONYMOUS_CODING              None
#
# [3 rows x 124 columns]

# %%
sdf.to_csv('/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients/mutations_for_oncoprint_124_patients.txt')
