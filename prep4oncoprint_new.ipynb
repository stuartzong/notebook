# %%
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib import style, colors
from matplotlib import gridspec

matplotlib.style.use('ggplot')
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (8, 6)

# %% [markdown]
# # make oncoprint for 124 patients

# %%
f1 ='/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/HIGH_MODERATE_INDEL_summary_with_normal_strelka_indels_only.tsv'
indf = pd.read_csv(f1, sep='\t')
indf.head(2)
# Out:
#    gene  num_patients_gene_level  num_INDELs_gene_level chromosome   position  \
# 0  PCNT                        1                      2         21   47849950
# 1  MLL3                       29                      6          7  151879476
#
#   ref_base alt_base  num_patients_INDEL_level         patient_ID     snp_ID  \
# 0     CAGG        C                         1  HTMCP-03-06-02448  novel_snp
# 1      CTG        C                         1  HTMCP-03-06-02097  novel_snp
#
#       ...      pileup_AltC pileup_AF strelka_n_Cov strelka_n_RefC  \
# 0     ...               na        na            41             43
# 1     ...               na        na            33             32
#
#   strelka_n_AltC strelka_n_AF strelka_t_Cov strelka_t_RefC strelka_t_AltC  \
# 0              0          0.0            83             62             15
# 1              0          0.0            84             56             22
#
#   strelka_t_AF
# 0         0.05
# 1         0.11
#
# [2 rows x 29 columns]

# %%
indf['impact_tmp'] = indf['snpeff_details'].apply(lambda x: x.split('(')[0])
indf = indf[['gene', 'patient_ID','impact_tmp']]
indf.head()
# Out:
#      gene         patient_ID      impact_tmp
# 0    PCNT  HTMCP-03-06-02448  CODON_DELETION
# 1    MLL3  HTMCP-03-06-02097     FRAME_SHIFT
# 2  MT-ND2  HTMCP-03-06-02174     FRAME_SHIFT
# 3  VPS13A  HTMCP-03-06-02012     FRAME_SHIFT
# 4    MSH6  HTMCP-03-06-02435     FRAME_SHIFT

# %%
# get gene list
# f2 = '/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients/genes.txt'
f2 = '/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/genes_grouped_for_oncoprint.txt'
cdf = pd.read_csv(f2, comment="#")
genes = cdf.genes.tolist()
print(genes)
# Out:
# ['MLL3', 'MLL2', 'CREBBP', 'EP300', 'ATRX', 'CHD4', 'CHD3', 'ARID1A', 'HCFC1', 'EZH2', 'MLL', 'BAZ2B', 'TAF1', 'TAF1L', 'KAT6A', 'TRRAP', 'KDM5B', 'EED', 'CHD1', 'CHD2', 'SF3B1', 'CACTIN', 'CDC5L', 'CHERP', 'CRNKL1', 'DDX46', 'DHX16', 'FAM50A', 'GPKOW', 'ISY1', 'MFAP1', 'PPIL2', 'PPWD1', 'RBM25', 'SF3A3', 'SMNDC1', 'SNRPD2', 'SNW1', 'U2AF1', 'U2SURP', 'ZRSR2', 'HLA-B', 'HLA-A', 'HLA-C', 'HLA-DRB5', 'HLA-DQB2', 'HLA-DQA1', 'C6', 'HLA-DRB1', 'C1RL', 'C3', 'B2M', 'HLA-DQA2', 'FAT1', 'FAT2', 'AJUBA', 'PIK3CA', 'FBXW7', 'CASP8', 'MAPK1', 'NFE2L2', 'TP53', 'ERBB2', 'ERBB3', 'PTEN', 'STK11', 'MED1', 'ELF3', 'CBFB', 'KRAS', 'TGFBR2']

# %%
# get meta track for example histology
f3 ='/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients/mutation_load_clinic.txt'
ddf = pd.read_csv(f3, sep='\t')
ddf = ddf[['patient', 'HIV_status', 'Putative_histology']]
edf = ddf.set_index('patient').T
edf.head(2)
# Out:
# patient            HTMCP-03-06-02001 HTMCP-03-06-02002 HTMCP-03-06-02003  \
# HIV_status                  Positive          Negative          Positive
# Putative_histology          Squamous          Squamous          Squamous
#
# patient            HTMCP-03-06-02006 HTMCP-03-06-02007 HTMCP-03-06-02008  \
# HIV_status                  Negative          Negative          Negative
# Putative_histology          Squamous             Adeno          Squamous
#
# patient            HTMCP-03-06-02012 HTMCP-03-06-02013 HTMCP-03-06-02020  \
# HIV_status                  Negative          Negative          Positive
# Putative_histology          Squamous          Squamous          Squamous
#
# patient            HTMCP-03-06-02026        ...        HTMCP-03-06-02424  \
# HIV_status                  Negative        ...                 Positive
# Putative_histology             Adeno        ...                 Squamous
#
# patient            HTMCP-03-06-02427 HTMCP-03-06-02428 HTMCP-03-06-02434  \
# HIV_status                  Positive          Positive          Positive
# Putative_histology          Squamous          Squamous          Squamous
#
# patient            HTMCP-03-06-02435 HTMCP-03-06-02437 HTMCP-03-06-02441  \
# HIV_status                  Positive          Positive          Positive
# Putative_histology          Squamous          Squamous             Adeno
#
# patient            HTMCP-03-06-02442 HTMCP-03-06-02447 HTMCP-03-06-02448
# HIV_status                  Positive          Positive          Positive
# Putative_histology          Squamous          Squamous             Adeno
#
# [2 rows x 123 columns]

# %%
# get snvs
# f4 = '/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients/124_patients_selected_columns_new_filtered.txt'
f4 = '/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/HIGH_MODERATE_SNV_summary_with_normal_with_AF_filtered_somatic.tsv'
pdf = pd.read_csv(f4, sep='\t')
pdf.head(2)
pdf['impact_tmp'] = pdf['snpeff_details'].apply(lambda x: x.split('(')[0])
mdf = pdf[['gene', 'patient_ID','impact_tmp']]
# Out:
# /home/szong/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mdf.head(2)
# Out:
#      gene         patient_ID             impact_tmp
# 0  SAMD11  HTMCP-03-06-02007  NON_SYNONYMOUS_CODING
# 1  SAMD11  HTMCP-03-06-02214  NON_SYNONYMOUS_CODING

# %%
# concat indel and snvs
rdf = pd.concat([mdf,indf])
rdf.head(2)
# Out:
#      gene         patient_ID             impact_tmp
# 0  SAMD11  HTMCP-03-06-02007  NON_SYNONYMOUS_CODING
# 1  SAMD11  HTMCP-03-06-02214  NON_SYNONYMOUS_CODING

# %%
rdf = rdf[rdf['patient_ID']!="HTMCP-03-06-02061"]

# %%
rdf = rdf.drop_duplicates().groupby(['gene', 'patient_ID']).agg({'impact_tmp': ','.join}).reset_index()
rdf.head(2)
# Out:
#    gene         patient_ID             impact_tmp
# 0  A1BG  HTMCP-03-06-02179  NON_SYNONYMOUS_CODING
# 1  A1CF  HTMCP-03-06-02020  NON_SYNONYMOUS_CODING

# %%
def impact_type(x):
#     print(x)
    xsplit = list(set(x.split(',')))
    type = xsplit[0].upper()
    if len(xsplit) > 1:
        impact = 'Multiple'
    elif len(xsplit) == 1:
         if '+' in xsplit[0]:
             impact = 'Multiple'
         elif type == 'MISSENSE_VARIANT' or type == 'NON_SYNONYMOUS_CODING':
             impact = 'NON_SYNONYMOUS_CODING'
         elif  type == 'SPLICE_SITE_ACCEPTOR' or  type == 'SPLICE_SITE_DONOR':
             impact = 'SPLICE_ACCEPTOR_DONOR'
         elif type == 'STOP_LOST':
             impact = 'STOP_LOST'
         elif type == 'STOP_GAINED':
             impact = 'STOP_GAINED'
         elif  type == 'START_LOST':
             impact = 'START_LOST'
         elif type == 'START_GAINED':
             impact = 'START_GAINED'
         elif type == 'FRAME_SHIFT' or type == 'FRAMESHIFT_VARIANT':
             impact = 'FRAME_SHIFT'
         elif type == 'INFRAME_DELETION' or type == 'CODON_INSERTION' or type == 'CODON_DELETION' or type == 'CODON_CHANGE_PLUS_CODON_INSERTION' or type == 'CODON_CHANGE_PLUS_CODON_DELETION' or type.lower() == 'disruptive_inframe_deletion':
             impact = 'CODON_INSERTION_DELETION'                
         else: exit(1);print('ERROR')
    return impact

# %%
rdf['impact'] = rdf['impact_tmp'].apply(lambda x: impact_type(x))
rdf = rdf[['gene', 'patient_ID', 'impact']].drop_duplicates()
rdf = rdf.set_index(['gene', 'patient_ID'])['impact'].unstack()
rdf.head(2)
# Out:
# patient_ID HTMCP-03-06-02001 HTMCP-03-06-02002 HTMCP-03-06-02003  \
# gene
# A1BG                    None              None              None
# A1CF                    None              None              None
#
# patient_ID HTMCP-03-06-02006 HTMCP-03-06-02007 HTMCP-03-06-02008  \
# gene
# A1BG                    None              None              None
# A1CF                    None              None              None
#
# patient_ID HTMCP-03-06-02012 HTMCP-03-06-02013      HTMCP-03-06-02020  \
# gene
# A1BG                    None              None                   None
# A1CF                    None              None  NON_SYNONYMOUS_CODING
#
# patient_ID HTMCP-03-06-02026        ...        HTMCP-03-06-02424  \
# gene                                ...
# A1BG                    None        ...                     None
# A1CF                    None        ...                     None
#
# patient_ID HTMCP-03-06-02427 HTMCP-03-06-02428 HTMCP-03-06-02434  \
# gene
# A1BG                    None              None              None
# A1CF                    None              None              None
#
# patient_ID HTMCP-03-06-02435 HTMCP-03-06-02437 HTMCP-03-06-02441  \
# gene
# A1BG                    None              None              None
# A1CF                    None              None              None
#
# patient_ID HTMCP-03-06-02442 HTMCP-03-06-02447 HTMCP-03-06-02448
# gene
# A1BG                    None              None              None
# A1CF                    None              None              None
#
# [2 rows x 123 columns]

# %%
# of3 = '/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/107_patients/mutations_in_oncoprint.txt'
# rdf.fillna('NA').to_csv(of3, sep='\t')

# %%
rdf = pd.concat([rdf, edf])

# %%
rdf.index
# Out:
# Index(['A1BG', 'A1CF', 'A2LD1', 'A2M', 'A2ML1', 'A4GALT', 'A4GNT', 'AAAS',
#        'AACS', 'AADAC',
#        ...
#        'ZXDC', 'ZYG11A', 'ZYG11B', 'ZZEF1', 'ZZZ3', 'hsa-mir-3187',
#        'hsa-mir-4763', 'yR211F11.2', 'HIV_status', 'Putative_histology'],
#       dtype='object', length=14587)

# %%
genes = [ 'HIV_status', 'Putative_histology'] + genes

# %%
rdf = rdf.reindex(genes)#.loc['PIK3CA'].value_counts()
rdf.head(3)
pd.Series(rdf.values.ravel()).unique()
# Out:
# array(['Positive', 'Negative', 'Squamous', 'Adeno',
#        'CODON_INSERTION_DELETION', None, 'Multiple', 'STOP_GAINED',
#        'NON_SYNONYMOUS_CODING', 'FRAME_SHIFT', 'SPLICE_ACCEPTOR_DONOR'], dtype=object)

# %%
rdf['occurrence'] = (rdf.notnull().sum(axis=1)/(rdf.shape[1] -2))

# %%
# genes = rdf['occurrence'].sort_values(ascending=False).index.tolist()
# predetermined gene order

# %%
rdf.head()
# Out:
#                            HTMCP-03-06-02001 HTMCP-03-06-02002  \
# HIV_status                          Positive          Negative
# Putative_histology                  Squamous          Squamous
# MLL3                CODON_INSERTION_DELETION              None
# MLL2                                    None       STOP_GAINED
# CREBBP                                  None              None
#
#                    HTMCP-03-06-02003 HTMCP-03-06-02006      HTMCP-03-06-02007  \
# HIV_status                  Positive          Negative               Negative
# Putative_histology          Squamous          Squamous                  Adeno
# MLL3                            None              None               Multiple
# MLL2                            None              None                   None
# CREBBP                          None              None  NON_SYNONYMOUS_CODING
#
#                    HTMCP-03-06-02008 HTMCP-03-06-02012 HTMCP-03-06-02013  \
# HIV_status                  Negative          Negative          Negative
# Putative_histology          Squamous          Squamous          Squamous
# MLL3                            None       STOP_GAINED              None
# MLL2                            None              None              None
# CREBBP                          None              None              None
#
#                    HTMCP-03-06-02020 HTMCP-03-06-02026    ...      \
# HIV_status                  Positive          Negative    ...
# Putative_histology          Squamous             Adeno    ...
# MLL3                     STOP_GAINED          Multiple    ...
# MLL2                            None              None    ...
# CREBBP                          None              None    ...
#
#                    HTMCP-03-06-02427      HTMCP-03-06-02428 HTMCP-03-06-02434  \
# HIV_status                  Positive               Positive          Positive
# Putative_histology          Squamous               Squamous          Squamous
# MLL3                            None  NON_SYNONYMOUS_CODING              None
# MLL2                            None                   None              None
# CREBBP                          None                   None              None
#
#                    HTMCP-03-06-02435 HTMCP-03-06-02437      HTMCP-03-06-02441  \
# HIV_status                  Positive          Positive               Positive
# Putative_histology          Squamous          Squamous                  Adeno
# MLL3                     STOP_GAINED              None  NON_SYNONYMOUS_CODING
# MLL2                     FRAME_SHIFT              None                   None
# CREBBP                          None              None                   None
#
#                    HTMCP-03-06-02442      HTMCP-03-06-02447 HTMCP-03-06-02448  \
# HIV_status                  Positive               Positive          Positive
# Putative_histology          Squamous               Squamous             Adeno
# MLL3                     STOP_GAINED  NON_SYNONYMOUS_CODING              None
# MLL2                            None                   None              None
# CREBBP                          None                   None              None
#
#                    occurrence
# HIV_status           1.016529
# Putative_histology   1.016529
# MLL3                 0.181818
# MLL2                 0.132231
# CREBBP               0.082645
#
# [5 rows x 124 columns]

# %%
(rdf.loc['MLL3',:] == 'STOP_GAINED').sum()
# Out:
# 8

# %%
# rdf = rdf.reindex(genes)
# rdf.head(2)

# %%
rdf['percentage'] = ['{0}({1}%)'.format(i[0], int(round(i[1]*100))) for i in zip(rdf.index.tolist(), rdf.occurrence)]

# %%
rdf.loc['HIV_status', 'percentage'] = 'HIV_Status'
rdf.loc['Putative_histology', 'percentage' ] = 'Puatative_Histology'

# %%
("HTMCP-03-06-02061" in rdf.columns)
# Out:
# False

# %%
rdf.head(3)
# Out:
#                            HTMCP-03-06-02001 HTMCP-03-06-02002  \
# HIV_status                          Positive          Negative
# Putative_histology                  Squamous          Squamous
# MLL3                CODON_INSERTION_DELETION              None
#
#                    HTMCP-03-06-02003 HTMCP-03-06-02006 HTMCP-03-06-02007  \
# HIV_status                  Positive          Negative          Negative
# Putative_histology          Squamous          Squamous             Adeno
# MLL3                            None              None          Multiple
#
#                    HTMCP-03-06-02008 HTMCP-03-06-02012 HTMCP-03-06-02013  \
# HIV_status                  Negative          Negative          Negative
# Putative_histology          Squamous          Squamous          Squamous
# MLL3                            None       STOP_GAINED              None
#
#                    HTMCP-03-06-02020 HTMCP-03-06-02026         ...           \
# HIV_status                  Positive          Negative         ...
# Putative_histology          Squamous             Adeno         ...
# MLL3                     STOP_GAINED          Multiple         ...
#
#                         HTMCP-03-06-02428 HTMCP-03-06-02434 HTMCP-03-06-02435  \
# HIV_status                       Positive          Positive          Positive
# Putative_histology               Squamous          Squamous          Squamous
# MLL3                NON_SYNONYMOUS_CODING              None       STOP_GAINED
#
#                    HTMCP-03-06-02437      HTMCP-03-06-02441 HTMCP-03-06-02442  \
# HIV_status                  Positive               Positive          Positive
# Putative_histology          Squamous                  Adeno          Squamous
# MLL3                            None  NON_SYNONYMOUS_CODING       STOP_GAINED
#
#                         HTMCP-03-06-02447 HTMCP-03-06-02448 occurrence  \
# HIV_status                       Positive          Positive   1.016529
# Putative_histology               Squamous             Adeno   1.016529
# MLL3                NON_SYNONYMOUS_CODING              None   0.181818
#
#                              percentage
# HIV_status                   HIV_Status
# Putative_histology  Puatative_Histology
# MLL3                          MLL3(18%)
#
# [3 rows x 125 columns]

# %%
sdf = rdf.drop('occurrence', axis=1).set_index('percentage', drop=True)

# %%
# sdf = sdf.fillna(0)

# %%
sdf.head(3)
# Out:
#                             HTMCP-03-06-02001 HTMCP-03-06-02002  \
# percentage
# HIV_Status                           Positive          Negative
# Puatative_Histology                  Squamous          Squamous
# MLL3(18%)            CODON_INSERTION_DELETION              None
#
#                     HTMCP-03-06-02003 HTMCP-03-06-02006 HTMCP-03-06-02007  \
# percentage
# HIV_Status                   Positive          Negative          Negative
# Puatative_Histology          Squamous          Squamous             Adeno
# MLL3(18%)                        None              None          Multiple
#
#                     HTMCP-03-06-02008 HTMCP-03-06-02012 HTMCP-03-06-02013  \
# percentage
# HIV_Status                   Negative          Negative          Negative
# Puatative_Histology          Squamous          Squamous          Squamous
# MLL3(18%)                        None       STOP_GAINED              None
#
#                     HTMCP-03-06-02020 HTMCP-03-06-02026        ...         \
# percentage                                                     ...
# HIV_Status                   Positive          Negative        ...
# Puatative_Histology          Squamous             Adeno        ...
# MLL3(18%)                 STOP_GAINED          Multiple        ...
#
#                          HTMCP-03-06-02424 HTMCP-03-06-02427  \
# percentage
# HIV_Status                        Positive          Positive
# Puatative_Histology               Squamous          Squamous
# MLL3(18%)            NON_SYNONYMOUS_CODING              None
#
#                          HTMCP-03-06-02428 HTMCP-03-06-02434  \
# percentage
# HIV_Status                        Positive          Positive
# Puatative_Histology               Squamous          Squamous
# MLL3(18%)            NON_SYNONYMOUS_CODING              None
#
#                     HTMCP-03-06-02435 HTMCP-03-06-02437  \
# percentage
# HIV_Status                   Positive          Positive
# Puatative_Histology          Squamous          Squamous
# MLL3(18%)                 STOP_GAINED              None
#
#                          HTMCP-03-06-02441 HTMCP-03-06-02442  \
# percentage
# HIV_Status                        Positive          Positive
# Puatative_Histology                  Adeno          Squamous
# MLL3(18%)            NON_SYNONYMOUS_CODING       STOP_GAINED
#
#                          HTMCP-03-06-02447 HTMCP-03-06-02448
# percentage
# HIV_Status                        Positive          Positive
# Puatative_Histology               Squamous             Adeno
# MLL3(18%)            NON_SYNONYMOUS_CODING              None
#
# [3 rows x 123 columns]

# %%
sdf.shape[1]
# Out:
# 123

# %%
assert ("HTMCP-03-06-02061" in sdf.columns) == False

# %%
sdf.to_csv('/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutations_for_oncoprint_123_patients.txt')
