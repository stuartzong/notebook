# %%
import csv
import re
import matplotlib
import seaborn
import string as s
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
import scipy.stats as ss
from matplotlib import style
from matplotlib.lines import Line2D
import lxml
import html5lib
# import beautifulsoup4 as bs4
from matplotlib import gridspec
# from matplotlib_venn import venn2, venn3, venn3_circles
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster, fclusterdata, leaves_list, cophenet
from scipy.spatial.distance import pdist
#pretty display
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

matplotlib.style.use('ggplot')
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (15, 9)


# %config InlineBackend.figure_format = 'retina'

# %%
f = '/projects/trans_scratch/validations/optitype/slurm/bbt_reads.txt'
df = pd.read_csv(f, header=None, sep='\t')
df.head()
df[3] = df[1]/4
minv = df[3].min()
sdf = df.sort_values(3)
sdf[sdf[0] == "POG237"]

p = sns.barplot(0, 3, data = sdf[[0, 3]])#, ci=None)
_ = plt.setp(p.get_xticklabels(), rotation=90)
_ = plt.title('HLA reads after bbt')
_ = plt.xlabel('')
_ = plt.ylabel('number of reads')
_ = plt.text(0, 120000, 'lowest number of reads = {}'.format(minv))
pass
of ='/projects/trans_scratch/validations/optitype/slurm/bbt_read_counts.png'
plt.savefig(of, dpi=200, bbox_inches='tight')
# Out:
#               0        1                                                  2
# 0  POG021-OCT-2   623700  /projects/trans_scratch/validations/BBT/hla_te...
# 1  POG093-OCT-1  1087756  /projects/trans_scratch/validations/BBT/hla_te...
# 2  POG138-OCT-1  1474640  /projects/trans_scratch/validations/BBT/hla_te...
# 3  POG230-OCT-1   332268  /projects/trans_scratch/validations/BBT/hla_te...
# 4  POG236-OCT-1   121380  /projects/trans_scratch/validations/BBT/hla_te...
#          0       1                                                  2  \
# 33  POG237  303760  /projects/trans_scratch/validations/BBT/hla_te...
# 32  POG237  898548  /projects/trans_scratch/validations/BBT/hla_te...
#
#            3
# 33   75940.0
# 32  224637.0
# /home/szong/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
